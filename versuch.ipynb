# %%
import numpy as np
import csv
from utils import basic_dict_2, read_db

# %%
material_dict = read_db()

# %%
material_dict
# Out:
# {'Walls,hard surfaces average (brick walls, plaster, hard floors, etc.)': [0.02,
#   0.02,
#   0.03,
#   0.03,
#   0.04,
#   0.05],
#  'Rough concrete': [0.02, 0.03, 0.03, 0.03, 0.04, 0.07],
#  'Smooth unpainted concrete': [0.01, 0.01, 0.02, 0.02, 0.02, 0.05],
#  'Ceramic tiles with a smooth surface': [0.01, 0.01, 0.01, 0.02, 0.02, 0.02],
#  'Concrete floor': [0.01, 0.03, 0.05, 0.02, 0.02, 0.02],
#  'Marble floor': [0.01, 0.01, 0.01, 0.02, 0.02, 0.02],
#  'Wooden lining, 12 mm fixed on frame': [0.27, 0.23, 0.22, 0.15, 0.1, 0.07],
#  'Single pane of glass, 3 mm': [0.08, 0.04, 0.03, 0.03, 0.02, 0.02],
#  'Glass window, 0.68 kg/m2': [0.1, 0.05, 0.04, 0.03, 0.03, 0.03],
#  'Double glazing, 2–3 mm glass,> 30 mm gap': [0.15,
#   0.05,
#   0.03,
#   0.03,
#   0.02,
#   0.02],
#  'Double glazing, 2–3 mm glass, 10 mm gap': [0.1,
#   0.07,
#   0.05,
#   0.03,
#   0.02,
#   0.02],
#  'Thin plywood panelling': [0.42, 0.21, 0.1, 0.08, 0.06, 0.06],
# ...

# %%
dict_db = csv.DictReader(open('Datenbank_Absorptionsgrade.csv'))
dict_obj = next(dict_db)

# %%
import csv
with open('Datenbank_Absorptionsgrade.csv', 'r', ) as file:
    reader = csv.reader(file, delimiter=';')
    header = next(reader)
    dict_db2 = {}
    for row in reader:
        key = row[0]
        values = row[1:]
        dict_db2[key] = [float(v) for v in values]

# %%
alpha_d =  basic_dict_2()
for key in material_dict:
    for value in material_dict[key]:
        print(value, key)
        #for i, freq in enumerate(alpha_d)
        #   alpha_d[freq].append(float(value[i]))
# Out:
# 0.02 Walls,hard surfaces average (brick walls, plaster, hard floors, etc.)
# 0.02 Walls,hard surfaces average (brick walls, plaster, hard floors, etc.)
# 0.03 Walls,hard surfaces average (brick walls, plaster, hard floors, etc.)
# 0.03 Walls,hard surfaces average (brick walls, plaster, hard floors, etc.)
# 0.04 Walls,hard surfaces average (brick walls, plaster, hard floors, etc.)
# 0.05 Walls,hard surfaces average (brick walls, plaster, hard floors, etc.)
# 0.02 Rough concrete
# 0.03 Rough concrete
# 0.03 Rough concrete
# 0.03 Rough concrete
# 0.04 Rough concrete
# 0.07 Rough concrete
# 0.01 Smooth unpainted concrete
# 0.01 Smooth unpainted concrete
# 0.02 Smooth unpainted concrete
# 0.02 Smooth unpainted concrete
# 0.02 Smooth unpainted concrete
# 0.05 Smooth unpainted concrete
# 0.01 Ceramic tiles with a smooth surface
# 0.01 Ceramic tiles with a smooth surface
# 0.01 Ceramic tiles with a smooth surface
# 0.02 Ceramic tiles with a smooth surface
# ...

# %%
dict_db2
# Out:
# {'Walls,hard surfaces average (brick walls, plaster, hard floors, etc.)': [0.02,
#   0.02,
#   0.03,
#   0.03,
#   0.04,
#   0.05],
#  'Rough concrete': [0.02, 0.03, 0.03, 0.03, 0.04, 0.07],
#  'Smooth unpainted concrete': [0.01, 0.01, 0.02, 0.02, 0.02, 0.05],
#  'Ceramic tiles with a smooth surface': [0.01, 0.01, 0.01, 0.02, 0.02, 0.02],
#  'Concrete floor': [0.01, 0.03, 0.05, 0.02, 0.02, 0.02],
#  'Marble floor': [0.01, 0.01, 0.01, 0.02, 0.02, 0.02],
#  'Wooden lining, 12 mm fixed on frame': [0.27, 0.23, 0.22, 0.15, 0.1, 0.07],
#  'Single pane of glass, 3 mm': [0.08, 0.04, 0.03, 0.03, 0.02, 0.02],
#  'Glass window, 0.68 kg/m2': [0.1, 0.05, 0.04, 0.03, 0.03, 0.03],
#  'Double glazing, 2–3 mm glass,> 30 mm gap': [0.15,
#   0.05,
#   0.03,
#   0.03,
#   0.02,
#   0.02],
#  'Double glazing, 2–3 mm glass, 10 mm gap': [0.1,
#   0.07,
#   0.05,
#   0.03,
#   0.02,
#   0.02],
#  'Thin plywood panelling': [0.42, 0.21, 0.1, 0.08, 0.06, 0.06],
# ...
